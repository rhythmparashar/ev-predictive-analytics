# %%
# Out:
# Running model report...
#
# Report: /Users/rhythmparashar/Desktop/ev-predictive-analytics/data/reports/model_analysis/dt=2026-03-01/vehicle_id=EV01
#
# Report Generated Successfully
#
# Report Folder:
# ../data/reports/model_analysis/dt=2026-03-01/vehicle_id=EV01
#
# ========== MODEL METRICS ==========
#
# Model MAE: 0.9883248209953308
# Model RMSE: 2.186681648858235
#
# Baseline MAE: 1.578768449929244
# Baseline RMSE: 2.1466353346562577
#
# MAE Improvement: 0.5904436289339132
#
# ========== RESIDUAL HISTOGRAM ==========
# ========== ERROR vs SOC ==========
# ========== ERROR vs POWER ==========
# ========== SHAP SUMMARY ==========
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Desktop/ev-predictive-analytics/venv/lib/python3.11/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# ...
